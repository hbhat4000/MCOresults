# %%
import pandas as pd

# %%
# load regular season data
df = pd.read_csv('events_2017-2018_pbp.csv',
                 usecols=[4,7,8,34,35,36,37,38,
                          91,92,93,94,95,
                         96,97,98,99,100])

# %%
colnames = pd.read_csv('colnames.csv',header=None)

# %%
# make a dictionary of all 5-person units
u2i = {}
i2u = {}
idctr = 0
for i in range(df.shape[0]):
    homekey = tuple(sorted(df.loc[i]['HOME_PLAYER_ID_1':'HOME_PLAYER_ID_5']))
    viskey = tuple(sorted(df.loc[i]['AWAY_PLAYER_ID_1':'AWAY_PLAYER_ID_5']))
    if homekey not in u2i:
        u2i[homekey] = idctr
        i2u[idctr] = homekey
        idctr += 1
    
    if viskey not in u2i:
        u2i[viskey] = idctr
        i2u[idctr] = viskey
        idctr += 1

# %%
import pickle

# %%
pickle.dump(u2i, open('u2i.pickle', 'wb'))
pickle.dump(i2u, open('i2u.pickle', 'wb'))

# %%
u2i[tuple(sorted([203926, 101127, 201584, 203124, 204001]))]
# Out:
# 1397

# %%
df.loc[480]
# Out:
# GAME_ID             21700014
# PCTIMESTRING           12:00
# PERIOD                     1
# HOME_TEAM              Bulls
# AWAY_TEAM            Raptors
# HOME_SCORE                 0
# AWAY_SCORE                 0
# TIME                       0
# HOME_PLAYER_ID_1      200768
# HOME_PLAYER_ID_2      201942
# HOME_PLAYER_ID_3      202685
# HOME_PLAYER_ID_4      201586
# HOME_PLAYER_ID_5     1626181
# AWAY_PLAYER_ID_1     1626170
# AWAY_PLAYER_ID_2      203200
# AWAY_PLAYER_ID_3      201577
# AWAY_PLAYER_ID_4     1628374
# AWAY_PLAYER_ID_5     1627835
# Name: 480, dtype: object

# %%
uniqteamnames = sorted(list(set(df['AWAY_TEAM'].append(df['HOME_TEAM']))))
print(uniqteamnames)
print(len(uniqteamnames))
# Out:
# ['76ers', 'Bucks', 'Bulls', 'Cavaliers', 'Celtics', 'Clippers', 'Grizzlies', 'Hawks', 'Heat', 'Hornets', 'Jazz', 'Kings', 'Knicks', 'Lakers', 'Magic', 'Mavericks', 'Nets', 'Nuggets', 'Pacers', 'Pelicans', 'Pistons', 'Raptors', 'Rockets', 'Spurs', 'Suns', 'Thunder', 'Timberwolves', 'Trail Blazers', 'Warriors', 'Wizards']
# 30

# %%
import numpy as np

# %%
def myprocess(mat):
    selection = np.ones(mat.shape[0],dtype='int32')
    for i in range(1,mat.shape[0]-1):
        if mat[i,0] == mat[i+1,0]:
            selection[i] = 0
    
    newmat = np.copy(mat)[np.where(selection)[0],:]
    return newmat

# %%
gametraj = {}
for tn in uniqteamnames:
    gametraj[tn] = {}


curgameid = -999999
for i in range(df.shape[0]):
    # check if current row is first row of new game
    if curgameid != df.loc[i]['GAME_ID']:
        curgameid = df.loc[i]['GAME_ID']
        tn = df.loc[i]['HOME_TEAM']
        times = []
        units = []
        teamscores = []
        opposcores = []
        print("Working on game ",curgameid)
        lastunit = -1
    
    # only append if there has been a substitution
    # or if it is the last row of this game
    homekey = tuple(sorted(df.loc[i]['HOME_PLAYER_ID_1':'HOME_PLAYER_ID_5']))
    curunit = u2i[homekey]
    curtime = df.loc[i]['TIME']
    lastrow = (i == (df.shape[0]-1)) or (curgameid != df.loc[i+1]['GAME_ID'])
    if (lastunit != curunit) or lastrow:
        units.append(curunit)
        times.append(curtime)
        teamscores.append(df.loc[i]['HOME_SCORE'])
        opposcores.append(df.loc[i]['AWAY_SCORE'])
        lastunit = curunit    
    
    # save trajectory matrix if current row is last row of this game
    if lastrow:
        # create matrix from game that was just finished
        trajmat = np.vstack([times, units, teamscores, opposcores]).T
        gametraj[tn][curgameid] = myprocess(trajmat)
# Out:
# Working on game  21700874
# Working on game  21700014
# Working on game  21701230
# Working on game  21700482
# Working on game  21700877
# Working on game  21700355
# Working on game  21700608
# Working on game  21700609
# Working on game  21700610
# Working on game  21700611
# Working on game  21700612
# Working on game  21700613
# Working on game  21700614
# Working on game  21700615
# Working on game  21700616
# Working on game  21700617
# Working on game  21700618
# Working on game  21700619
# Working on game  21700620
# Working on game  21700621
# Working on game  21700622
# Working on game  21700623
# Working on game  21700624
# Working on game  21700625
# Working on game  21700626
# Working on game  21700627
# Working on game  21700628
# Working on game  21700629
# Working on game  21700630
# Working on game  21700631
# Working on game  21700632
# Working on game  21700633
# Working on game  21700634
# Working on game  21700635
# Working on game  21700636
# Working on game  21700637
# Working on game  21700638
# Working on game  21700639
# Working on game  21700640
# Working on game  21700641
# Working on game  21700642
# Working on game  21700643
# Working on game  21700644
# Working on game  21700645
# Working on game  21700646
# Working on game  21700647
# Working on game  21700648
# Working on game  21700649
# Working on game  21700650
# Working on game  21700651
# Working on game  21700652
# Working on game  21700653
# Working on game  21700654
# Working on game  21700655
# Working on game  21700656
# Working on game  21700657
# Working on game  21700658
# Working on game  21700659
# Working on game  21700660
# Working on game  21700661
# Working on game  21700662
# Working on game  21700663
# Working on game  21700664
# Working on game  21700665
# Working on game  21700666
# Working on game  21700667
# Working on game  21700668
# Working on game  21700669
# Working on game  21700670
# Working on game  21700671
# Working on game  21700672
# Working on game  21700673
# Working on game  21700674
# Working on game  21700675
# Working on game  21700676
# Working on game  21700677
# Working on game  21700678
# Working on game  21700679
# Working on game  21700680
# Working on game  21700681
# Working on game  21700682
# Working on game  21700683
# Working on game  21700684
# Working on game  21700685
# Working on game  21700686
# Working on game  21700687
# Working on game  21700688
# Working on game  21700689
# Working on game  21700690
# Working on game  21700691
# Working on game  21700692
# Working on game  21700693
# Working on game  21700694
# Working on game  21700695
# Working on game  21700696
# Working on game  21700697
# Working on game  21700698
# Working on game  21700699
# Working on game  21700700
# Working on game  21700701
# Working on game  21700702
# Working on game  21700703
# Working on game  21700704
# Working on game  21700705
# Working on game  21700706
# Working on game  21700707
# Working on game  21700708
# Working on game  21700709
# Working on game  21700710
# Working on game  21700711
# Working on game  21700712
# Working on game  21700713
# Working on game  21700714
# Working on game  21700715
# Working on game  21700716
# Working on game  21700717
# Working on game  21700718
# Working on game  21700719
# Working on game  21701024
# Working on game  21701025
# Working on game  21701026
# Working on game  21701027
# Working on game  21701028
# Working on game  21701029
# Working on game  21701030
# Working on game  21701031
# Working on game  21701032
# Working on game  21701033
# Working on game  21701034
# Working on game  21701035
# Working on game  21701036
# Working on game  21701037
# Working on game  21701038
# Working on game  21701039
# Working on game  21701040
# Working on game  21701041
# Working on game  21701042
# Working on game  21701043
# Working on game  21701044
# Working on game  21701045
# Working on game  21701046
# Working on game  21701047
# Working on game  21701048
# Working on game  21701049
# Working on game  21701050
# Working on game  21701051
# Working on game  21701052
# Working on game  21701053
# Working on game  21701054
# Working on game  21701055
# Working on game  21701056
# Working on game  21701057
# Working on game  21701058
# Working on game  21701059
# Working on game  21701060
# Working on game  21701061
# Working on game  21701062
# Working on game  21701063
# Working on game  21701064
# Working on game  21701065
# Working on game  21701066
# Working on game  21701067
# Working on game  21701068
# Working on game  21701069
# Working on game  21701070
# Working on game  21701071
# Working on game  21701072
# Working on game  21701073
# Working on game  21701074
# Working on game  21701075
# Working on game  21701076
# Working on game  21701077
# Working on game  21701078
# Working on game  21701079
# Working on game  21701080
# Working on game  21701081
# Working on game  21701082
# Working on game  21701083
# Working on game  21701084
# Working on game  21701085
# Working on game  21701086
# Working on game  21701087
# Working on game  21701088
# Working on game  21701089
# Working on game  21701090
# Working on game  21701091
# Working on game  21701092
# Working on game  21701093
# Working on game  21701094
# Working on game  21701095
# Working on game  21701096
# Working on game  21701097
# Working on game  21701098
# Working on game  21701099
# Working on game  21701100
# Working on game  21701101
# Working on game  21701102
# Working on game  21701103
# Working on game  21701104
# Working on game  21701105
# Working on game  21701106
# Working on game  21701107
# Working on game  21701108
# Working on game  21701109
# Working on game  21701110
# Working on game  21701111
# Working on game  21701112
# Working on game  21701113
# Working on game  21701114
# Working on game  21701115
# Working on game  21701116
# Working on game  21701117
# Working on game  21701118
# Working on game  21701119
# Working on game  21701120
# Working on game  21701121
# Working on game  21701122
# Working on game  21701123
# Working on game  21701124
# Working on game  21701125
# Working on game  21701126
# Working on game  21701127
# Working on game  21701128
# Working on game  21701129
# Working on game  21701130
# Working on game  21701131
# Working on game  21701132
# Working on game  21701133
# Working on game  21701134
# Working on game  21701135
# Working on game  21701136
# Working on game  21701137
# Working on game  21701138
# Working on game  21701139
# Working on game  21701140
# Working on game  21701141
# Working on game  21701142
# Working on game  21701143
# Working on game  21701144
# Working on game  21701145
# Working on game  21701146
# Working on game  21701147
# Working on game  21701148
# Working on game  21701149
# Working on game  21701150
# Working on game  21701151
# Working on game  21701152
# Working on game  21701153
# Working on game  21701154
# Working on game  21701155
# Working on game  21701156
# Working on game  21701157
# Working on game  21701158
# Working on game  21701159
# Working on game  21701160
# Working on game  21701161
# Working on game  21701162
# Working on game  21701163
# Working on game  21701164
# Working on game  21701165
# Working on game  21701166
# Working on game  21701167
# Working on game  21701168
# Working on game  21701169
# Working on game  21701170
# Working on game  21701171
# Working on game  21701172
# Working on game  21701173
# Working on game  21701174
# Working on game  21701175
# Working on game  21701176
# Working on game  21701177
# Working on game  21701178
# Working on game  21701179
# Working on game  21701180
# Working on game  21701181
# Working on game  21701182
# Working on game  21701183
# Working on game  21701184
# Working on game  21701185
# Working on game  21701186
# Working on game  21701187
# Working on game  21701188
# Working on game  21701189
# Working on game  21701190
# Working on game  21701191
# Working on game  21701192
# Working on game  21701193
# Working on game  21701194
# Working on game  21701195
# Working on game  21701196
# Working on game  21701197
# Working on game  21701198
# Working on game  21701199
# Working on game  21701200
# Working on game  21701201
# Working on game  21701202
# Working on game  21701203
# Working on game  21701204
# Working on game  21701205
# Working on game  21701206
# Working on game  21701207
# Working on game  21701208
# Working on game  21701209
# Working on game  21701210
# Working on game  21701211
# Working on game  21701212
# Working on game  21701213
# Working on game  21701214
# Working on game  21701215
# Working on game  21701216
# Working on game  21701217
# Working on game  21701218
# Working on game  21701219
# Working on game  21701220
# Working on game  21701221
# Working on game  21701222
# Working on game  21701223
# Working on game  21701224
# Working on game  21701225
# Working on game  21701226
# Working on game  21701227
# Working on game  21701228
# Working on game  21701229
# Working on game  21700001
# Working on game  21700002
# Working on game  21700003
# Working on game  21700004
# Working on game  21700005
# Working on game  21700006
# Working on game  21700007
# Working on game  21700008
# Working on game  21700009
# Working on game  21700010
# Working on game  21700011
# Working on game  21700012
# Working on game  21700013
# Working on game  21700015
# Working on game  21700016
# Working on game  21700017
# Working on game  21700018
# Working on game  21700019
# Working on game  21700020
# Working on game  21700021
# Working on game  21700022
# Working on game  21700023
# Working on game  21700024
# Working on game  21700025
# Working on game  21700026
# Working on game  21700027
# Working on game  21700028
# Working on game  21700029
# Working on game  21700030
# Working on game  21700031
# Working on game  21700032
# Working on game  21700033
# Working on game  21700034
# Working on game  21700035
# Working on game  21700036
# Working on game  21700037
# Working on game  21700038
# Working on game  21700039
# Working on game  21700040
# Working on game  21700041
# Working on game  21700042
# Working on game  21700043
# Working on game  21700044
# Working on game  21700045
# Working on game  21700046
# Working on game  21700047
# Working on game  21700048
# Working on game  21700049
# Working on game  21700050
# Working on game  21700051
# Working on game  21700052
# Working on game  21700053
# Working on game  21700054
# Working on game  21700055
# Working on game  21700056
# Working on game  21700057
# Working on game  21700058
# Working on game  21700059
# Working on game  21700060
# Working on game  21700061
# Working on game  21700062
# Working on game  21700063
# Working on game  21700064
# Working on game  21700065
# Working on game  21700066
# Working on game  21700067
# Working on game  21700068
# Working on game  21700069
# Working on game  21700070
# Working on game  21700071
# Working on game  21700072
# Working on game  21700073
# Working on game  21700074
# Working on game  21700075
# Working on game  21700076
# Working on game  21700077
# Working on game  21700078
# Working on game  21700079
# Working on game  21700080
# Working on game  21700081
# Working on game  21700082
# Working on game  21700083
# Working on game  21700084
# Working on game  21700085
# Working on game  21700086
# Working on game  21700087
# Working on game  21700088
# Working on game  21700089
# Working on game  21700090
# Working on game  21700091
# Working on game  21700092
# Working on game  21700093
# Working on game  21700094
# Working on game  21700095
# Working on game  21700096
# Working on game  21700097
# Working on game  21700249
# Working on game  21700250
# Working on game  21700251
# Working on game  21700252
# Working on game  21700253
# Working on game  21700254
# Working on game  21700255
# Working on game  21700256
# Working on game  21700257
# Working on game  21700258
# Working on game  21700259
# Working on game  21700260
# Working on game  21700261
# Working on game  21700262
# Working on game  21700263
# Working on game  21700264
# Working on game  21700265
# Working on game  21700266
# Working on game  21700267
# Working on game  21700268
# Working on game  21700269
# Working on game  21700270
# Working on game  21700271
# Working on game  21700272
# Working on game  21700273
# Working on game  21700274
# Working on game  21700275
# Working on game  21700276
# Working on game  21700277
# Working on game  21700278
# Working on game  21700279
# Working on game  21700280
# Working on game  21700281
# Working on game  21700282
# Working on game  21700283
# Working on game  21700284
# Working on game  21700285
# Working on game  21700286
# Working on game  21700287
# Working on game  21700288
# Working on game  21700289
# Working on game  21700290
# Working on game  21700291
# Working on game  21700292
# Working on game  21700293
# Working on game  21700294
# Working on game  21700295
# Working on game  21700296
# Working on game  21700297
# Working on game  21700298
# Working on game  21700299
# Working on game  21700300
# Working on game  21700301
# Working on game  21700302
# Working on game  21700303
# Working on game  21700304
# Working on game  21700305
# Working on game  21700306
# Working on game  21700307
# Working on game  21700308
# Working on game  21700309
# Working on game  21700310
# Working on game  21700311
# Working on game  21700312
# Working on game  21700313
# Working on game  21700314
# Working on game  21700315
# Working on game  21700316
# Working on game  21700317
# Working on game  21700318
# Working on game  21700319
# Working on game  21700320
# Working on game  21700321
# Working on game  21700322
# Working on game  21700323
# Working on game  21700324
# Working on game  21700325
# Working on game  21700326
# Working on game  21700327
# Working on game  21700328
# Working on game  21700329
# Working on game  21700330
# Working on game  21700331
# Working on game  21700332
# Working on game  21700333
# Working on game  21700334
# Working on game  21700335
# Working on game  21700336
# Working on game  21700337
# Working on game  21700338
# Working on game  21700339
# Working on game  21700340
# Working on game  21700341
# Working on game  21700342
# Working on game  21700343
# Working on game  21700344
# Working on game  21700345
# Working on game  21700346
# Working on game  21700347
# Working on game  21700348
# Working on game  21700349
# Working on game  21700350
# Working on game  21700351
# Working on game  21700352
# Working on game  21700353
# Working on game  21700354
# Working on game  21700356
# Working on game  21700357
# Working on game  21700358
# Working on game  21700359
# Working on game  21700360
# Working on game  21700361
# Working on game  21700362
# Working on game  21700363
# Working on game  21700364
# Working on game  21700365
# Working on game  21700366
# Working on game  21700367
# Working on game  21700368
# Working on game  21700369
# Working on game  21700370
# Working on game  21700371
# Working on game  21700372
# Working on game  21700373
# Working on game  21700374
# Working on game  21700375
# Working on game  21700376
# Working on game  21700377
# Working on game  21700378
# Working on game  21700379
# Working on game  21700380
# Working on game  21700381
# Working on game  21700382
# Working on game  21700383
# Working on game  21700384
# Working on game  21700385
# Working on game  21700386
# Working on game  21700387
# Working on game  21700388
# Working on game  21700389
# Working on game  21700390
# Working on game  21700391
# Working on game  21700392
# Working on game  21700393
# Working on game  21700394
# Working on game  21700395
# Working on game  21700396
# Working on game  21700397
# Working on game  21700398
# Working on game  21700399
# Working on game  21700400
# Working on game  21700553
# Working on game  21700554
# Working on game  21700555
# Working on game  21700556
# Working on game  21700557
# Working on game  21700558
# Working on game  21700559
# Working on game  21700560
# Working on game  21700561
# Working on game  21700562
# Working on game  21700563
# Working on game  21700564
# Working on game  21700565
# Working on game  21700566
# Working on game  21700567
# Working on game  21700568
# Working on game  21700569
# Working on game  21700570
# Working on game  21700571
# Working on game  21700572
# Working on game  21700573
# Working on game  21700574
# Working on game  21700575
# Working on game  21700576
# Working on game  21700577
# Working on game  21700578
# Working on game  21700579
# Working on game  21700580
# Working on game  21700581
# Working on game  21700582
# Working on game  21700583
# Working on game  21700584
# Working on game  21700585
# Working on game  21700586
# Working on game  21700587
# Working on game  21700588
# Working on game  21700589
# Working on game  21700590
# Working on game  21700591
# Working on game  21700592
# Working on game  21700593
# Working on game  21700594
# Working on game  21700595
# Working on game  21700596
# Working on game  21700597
# Working on game  21700598
# Working on game  21700599
# Working on game  21700600
# Working on game  21700601
# Working on game  21700602
# Working on game  21700603
# Working on game  21700604
# Working on game  21700605
# Working on game  21700606
# Working on game  21700607

# %%
pickle.dump(gametraj, open('gametrajhalf.pickle', 'wb'))

# %%
curgameid = -999999
for i in range(df.shape[0]):
    # check if current row is first row of new game
    if curgameid != df.loc[i]['GAME_ID']:
        curgameid = df.loc[i]['GAME_ID']
        tn = df.loc[i]['AWAY_TEAM']
        times = []
        units = []
        teamscores = []
        opposcores = []
        print("Working on game ",curgameid)
        lastunit = -1
    
    # only append if there has been a substitution
    # or if it is the last row of this game
    viskey = tuple(sorted(df.loc[i]['AWAY_PLAYER_ID_1':'AWAY_PLAYER_ID_5']))
    curunit = u2i[viskey]
    curtime = df.loc[i]['TIME']
    lastrow = (i == (df.shape[0]-1)) or (curgameid != df.loc[i+1]['GAME_ID'])
    if (lastunit != curunit) or lastrow:
        units.append(curunit)
        times.append(curtime)
        teamscores.append(df.loc[i]['AWAY_SCORE'])
        opposcores.append(df.loc[i]['HOME_SCORE'])
        lastunit = curunit
    
    # save trajectory matrix if current row is last row of this game
    if lastrow:
        # create matrix from game that was just finished
        trajmat = np.vstack([times, units, teamscores, opposcores]).T
        gametraj[tn][curgameid] = myprocess(trajmat)
# Out:
# Working on game  21700874
# Working on game  21700014
# Working on game  21701230
# Working on game  21700482
# Working on game  21700877
# Working on game  21700355
# Working on game  21700608
# Working on game  21700609
# Working on game  21700610
# Working on game  21700611
# Working on game  21700612
# Working on game  21700613
# Working on game  21700614
# Working on game  21700615
# Working on game  21700616
# Working on game  21700617
# Working on game  21700618
# Working on game  21700619
# Working on game  21700620
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-b5e1563907dd> in <module>()
#      29         # create matrix from game that was just finished
#      30         trajmat = np.vstack([times, units, teamscores, opposcores]).T
# ---> 31         gametraj[tn][curgameid] = myprocess(trajmat)
#      32
#
# KeyError: 'Wizards'

# %%
pickle.dump(gametraj, open('gametraj.pickle', 'wb'))

# %%
# remaining steps
# map out states+score vs time for all games
# consider cross-product space
# compute MLEs
# compute accuracies etc
# regularize
